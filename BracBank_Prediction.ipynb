# %% [markdown]
# <a href="https://colab.research.google.com/github/ARPRAHMAN/Banking-Stock-Price-Prediction-in-DSE/blob/main/BracBank_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
# Adjust the path to your file location
file_path = '/content/drive/MyDrive/0Thesis Dataset/brac bank/BracBank.csv'
df = pd.read_csv(file_path)
df.head(10)
# Out:
#        Name        Date  Open  High   Low  Close  Volume
# 0  BRACBANK  05-12-2011  45.0  45.0  43.9   44.2  225500
# 1  BRACBANK  07-12-2011  43.5  44.1  42.9   43.3  228500
# 2  BRACBANK  08-12-2011  43.0  43.0  42.0   42.3  264000
# 3  BRACBANK  11-12-2011  41.1  42.0  41.1   41.6  182000
# 4  BRACBANK  12-12-2011  41.2  42.0  41.1   41.7  199500
# 5  BRACBANK  13-12-2011  41.4  44.9  41.4   44.2  364500
# 6  BRACBANK  14-12-2011  44.9  46.7  43.2   43.8  476080
# 7  BRACBANK  15-12-2011  44.4  45.9  43.6   44.1  206000
# 8  BRACBANK  18-12-2011  44.7  44.7  43.4   44.1  175500
# 9  BRACBANK  19-12-2011  44.0  45.5  44.0   45.2  261500

# %%
# Check null value count per column
print("Null value count in raw dataset (df):")
print(df.isnull().sum())
# Out:
# Null value count in raw dataset (df):
# Name      0
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
# Drop rows that are completely null
df = df.dropna(how='all')

# Verify
print(df.isnull().sum())
# Out:
# Name      0
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %% [markdown]
# **Check few thing and change it:**
#
# 1.   Remove Name column
# 2.   Date sortation format (dd-mm-yyyy)

# %%
import pandas as pd

# Create new dataset from raw df
dataset = df.copy()

# Convert date and sort
dataset['Date_dt'] = pd.to_datetime(
    dataset['Date'],
    format='%d-%m-%Y'
)

dataset = dataset.sort_values('Date_dt').reset_index(drop=True)

# Drop helper and unnecessary columns
dataset = dataset.drop(columns=['Date_dt'])
dataset = dataset.drop(columns=['Name'])

# Save clean dataset
dataset.to_csv(
    "/content/drive/MyDrive/0Thesis Dataset/brac bank/BracFinal_clean.csv",
    index=False
)

print("Dataset sorted, 'Name' column removed, and saved as BracFinal_clean.csv")
# Out:
# Dataset sorted, 'Name' column removed, and saved as BracFinal_clean.csv

# %%
dataset.head()
# Out:
#          Date  Open  High   Low  Close  Volume
# 0  05-12-2011  45.0  45.0  43.9   44.2  225500
# 1  07-12-2011  43.5  44.1  42.9   43.3  228500
# 2  08-12-2011  43.0  43.0  42.0   42.3  264000
# 3  11-12-2011  41.1  42.0  41.1   41.6  182000
# 4  12-12-2011  41.2  42.0  41.1   41.7  199500

# %% [markdown]
# **Chart**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv(
    "/content/drive/MyDrive/0Thesis Dataset/brac bank/BracFinal_clean.csv"
)

# Convert Date to datetime (safe)
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# Plot Closing Price vs Time
plt.figure(figsize=(12, 5))
plt.plot(df['Date'], df['Close'])
plt.xlabel("Time")
plt.ylabel("Closing Price")
plt.title("Closing Price vs Time")
plt.grid(True)
plt.show()

# %%
print(dataset.isnull().sum())
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %% [markdown]
# *## Correlation check before add new or more features*

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ================================
# DEFINE TARGET
# ================================
dataset['Target_Close'] = dataset['Close'].shift(-1)

# Drop only last row (no future target)
corr_df = dataset.dropna().reset_index(drop=True)

# ================================
# BASE FEATURES
# ================================
base_features = ['Open', 'High', 'Low', 'Close', 'Volume']

# ================================
# CORRELATION WITH TARGET
# ================================
corr = corr_df[base_features + ['Target_Close']].corr()
target_corr = corr['Target_Close'].drop('Target_Close')

print("Correlation with Target_Close:\n")
print(target_corr.sort_values(ascending=False))
# Out:
# Correlation with Target_Close:
#
# Close     0.997864
# High      0.994995
# Low       0.994799
# Open      0.993854
# Volume    0.193428
# Name: Target_Close, dtype: float64

# %% [markdown]
# **Diagram for better visual**

# %%
# ================================
# SCATTER DIAGRAMS
# ================================
for feature in base_features:
    plt.figure()
    plt.scatter(corr_df[feature], corr_df['Target_Close'])
    plt.xlabel(feature)
    plt.ylabel("Target_Close")
    plt.title(f"{feature} vs Target_Close")
    plt.show()

# %% [markdown]
# ***Add new and more features which is showing some patterns with target features***

# %%
# ================================
#  CREATE FINAL DATASET COPY
# ================================
df_final = dataset.copy()

# ================================
# PRICE-BASED FEATURES
# ================================
df_final['price_change'] = df_final['Close'] - df_final['Close'].shift(1)
df_final['log_return'] = np.log(df_final['Close'] / df_final['Close'].shift(1))
df_final['daily_range'] = df_final['High'] - df_final['Low']
df_final['typical_price'] = (
    df_final['High'] + df_final['Low'] + df_final['Close']
) / 3

# ================================
# VOLUME FEATURES
# ================================
df_final['volume_change'] = df_final['Volume'].pct_change(fill_method=None)

# ================================
#  TREND INDICATORS
# ================================
df_final['SMA_10'] = df_final['Close'].rolling(10).mean()
df_final['SMA_20'] = df_final['Close'].rolling(20).mean()

df_final['EMA_10'] = df_final['Close'].ewm(span=10, adjust=False).mean()
df_final['EMA_20'] = df_final['Close'].ewm(span=20, adjust=False).mean()

# ================================
#  MACD
# ================================
ema12 = df_final['Close'].ewm(span=12, adjust=False).mean()
ema26 = df_final['Close'].ewm(span=26, adjust=False).mean()

df_final['MACD'] = ema12 - ema26
df_final['MACD_signal'] = df_final['MACD'].ewm(span=9, adjust=False).mean()

# ================================
#  RSI (14)
# ================================
delta = df_final['Close'].diff()
gain = delta.clip(lower=0)
loss = -delta.clip(upper=0)

avg_gain = gain.rolling(14).mean()
avg_loss = loss.rolling(14).mean()

rs = avg_gain / avg_loss
df_final['RSI_14'] = 100 - (100 / (1 + rs))

# ================================
#  BOLLINGER BANDS
# ================================
bb_middle = df_final['Close'].rolling(20).mean()
bb_std = df_final['Close'].rolling(20).std()

df_final['BB_middle'] = bb_middle
df_final['BB_upper'] = bb_middle + 2 * bb_std
df_final['BB_lower'] = bb_middle - 2 * bb_std
df_final['BB_width'] = (df_final['BB_upper'] - df_final['BB_lower']) / bb_middle

# ================================
#  VOLATILITY / RISK
# ================================
df_final['rolling_std_14'] = df_final['log_return'].rolling(14).std()

# ================================
#  TARGET (NEXT-DAY CLOSE)
# ================================
df_final['Target_Close'] = df_final['Close'].shift(-1)

# ================================
#  CLEAN FINAL DATASET
# ================================
df_final = df_final.dropna().reset_index(drop=True)

# ================================
#  SAVE FINAL FEATURE DATASET
# ================================
df_final.to_csv(
    "/content/drive/MyDrive/0Thesis Dataset/brac bank/Feature-added-BracBank.csv",
    index=False,
    lineterminator="\r\n"
)

print("Final feature dataset created successfully")
print("Saved as: BracFinal_features_ML.csv")
# Out:
# Final feature dataset created successfully
# Saved as: BracFinal_features_ML.csv

# %%
df_final.head()
# Out:
#          Date  Open  High   Low  Close  Volume  Target_Close  price_change  \
# 0  03-01-2012  45.0  45.3  44.7   44.8  333500          46.0          -0.3
# 1  04-01-2012  45.8  46.2  45.1   46.0  360500          46.6           1.2
# 2  05-01-2012  46.4  47.1  46.3   46.6  482000          45.6           0.6
# 3  08-01-2012  46.3  47.0  45.5   45.6  288800          43.9          -1.0
# 4  09-01-2012  45.5  45.8  43.8   43.9  317500          43.1          -1.7
#
#    log_return  daily_range  ...     EMA_10     EMA_20      MACD  MACD_signal  \
# 0   -0.006674          0.6  ...  45.195225  44.864129  0.396471     0.363584
# 1    0.026433          1.1  ...  45.341548  44.972307  0.436877     0.378243
# 2    0.012959          0.8  ...  45.570357  45.127326  0.511419     0.404878
# 3   -0.021693          1.5  ...  45.575747  45.172342  0.484220     0.420746
# 4   -0.037993          2.0  ...  45.271066  45.051167  0.321780     0.400953
#
#       RSI_14  BB_middle   BB_upper   BB_lower  BB_width  rolling_std_14
# 0  54.545455     44.470  47.268571  41.671429  0.125863        0.013548
# 1  64.864865     44.560  47.436694  41.683306  0.129116        0.014790
# 2  66.233766     44.725  47.675022  41.774978  0.131918        0.014985
# 3  58.620690     44.890  47.630649  42.149351  0.122105        0.016472
# 4  43.010753     45.005  47.325141  42.684859  0.103106        0.018361
#
# [5 rows x 24 columns]

# %% [markdown]
# **Now check correlation with all the features (newly added also)**

# %%
# ================================
# CORRELATION WITH TARGET
# ================================
corr = df_final.corr(numeric_only=True)

target_corr = corr['Target_Close'].drop('Target_Close')

# Sort by absolute importance
target_corr = target_corr.sort_values(key=abs, ascending=False)

print("Correlation with Target_Close:\n")
print(target_corr)
# Out:
# Correlation with Target_Close:
#
# Close             0.997802
# typical_price     0.996609
# High              0.994849
# Low               0.994669
# Open              0.993667
# EMA_10            0.992908
# SMA_10            0.990819
# EMA_20            0.987693
# SMA_20            0.983785
# BB_middle         0.983785
# BB_upper          0.973011
# BB_lower          0.971537
# daily_range       0.513601
# MACD_signal       0.229216
# MACD              0.222073
# Volume            0.166647
# RSI_14            0.153866
# price_change      0.040403
# rolling_std_14   -0.036624
# log_return        0.036445
# volume_change    -0.024683
# BB_width         -0.018151
# Name: Target_Close, dtype: float64

# %% [markdown]
# **Diagram**

# %%
# ================================
# SELECT NUMERIC FEATURES
# ================================
numeric_features = df_final.select_dtypes(include='number').columns.tolist()

# Remove target from feature list
numeric_features.remove('Target_Close')

# ================================
# SCATTER DIAGRAMS
# ================================
for feature in numeric_features:
    plt.figure()
    plt.scatter(df_final[feature], df_final['Target_Close'])
    plt.xlabel(feature)
    plt.ylabel("Target_Close")
    plt.title(f"{feature} vs Target_Close")
    plt.show()

# %% [markdown]
# Create a dataset where only high correlated features only name as : **df_selected**

# %%
import pandas as pd

# ============================================
# FEATURE SELECTION (CORRELATION-BASED)
# ============================================
# -----------------------------
# Selected features based on correlation analysis
# -----------------------------
selected_features = [
    'Close',
    'typical_price',
    'High',
    'Low',
    'Open',
    'EMA_10',
    'SMA_10',
    'EMA_20',
    'SMA_20',
    'BB_middle',
    'BB_upper',
    'BB_lower'
]

target_column = 'Target_Close'

# -----------------------------
# Create selected-feature dataset
# -----------------------------
df_selected = df_final[selected_features + [target_column]].copy()

# -----------------------------
# Save selected-feature dataset
# -----------------------------
df_selected.to_csv(
    "/content/drive/MyDrive/0Thesis Dataset/brac bank/Select_features_BracFinal.csv",
    index=False,
    lineterminator="\r\n"
)

print("Feature selection completed successfully")
print(f" Selected features: {len(selected_features)}")
print(" Saved as: BracFinal_selected_features.csv")
# Out:
# Feature selection completed successfully
#  Selected features: 12
#  Saved as: BracFinal_selected_features.csv

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# ================================
# SELECTED FEATURES
# ================================
selected_features = [
    'Close',
    'typical_price',
    'High',
    'Low',
    'Open',
    'EMA_10',
    'SMA_10',
    'EMA_20',
    'SMA_20',
    'BB_middle',
    'BB_upper',
    'BB_lower'
]

# ================================
# CORRELATION HEATMAP
# ================================
plt.figure(figsize=(10, 6))

sns.heatmap(
    df_selected[selected_features].corr(),
    cmap='coolwarm',
    annot=True,        # show values (good for thesis)
    fmt=".2f",
    linewidths=0.5
)

plt.title("Correlation Heatmap of Selected Features")
plt.tight_layout()
plt.show()

# %%
df_selected.head()
# Out:
#    Close  typical_price  High   Low  Open     EMA_10  SMA_10     EMA_20  \
# 0   44.8      44.933333  45.3  44.7  45.0  45.195225   45.49  44.864129
# 1   46.0      45.766667  46.2  45.1  45.8  45.341548   45.62  44.972307
# 2   46.6      46.666667  47.1  46.3  46.4  45.570357   45.79  45.127326
# 3   45.6      46.033333  47.0  45.5  46.3  45.575747   45.72  45.172342
# 4   43.9      44.500000  45.8  43.8  45.5  45.271066   45.54  45.051167
#
#    SMA_20  BB_middle   BB_upper   BB_lower  Target_Close
# 0  44.470     44.470  47.268571  41.671429          46.0
# 1  44.560     44.560  47.436694  41.683306          46.6
# 2  44.725     44.725  47.675022  41.774978          45.6
# 3  44.890     44.890  47.630649  42.149351          43.9
# 4  45.005     45.005  47.325141  42.684859          43.1

# %%
df_selected.describe()
# Out:
#              Close  typical_price         High          Low         Open  \
# count  2863.000000    2863.000000  2863.000000  2863.000000  2863.000000
# mean     51.853475      51.862906    52.584143    51.151100    51.850332
# std      19.416742      19.462158    19.785073    19.233791    19.543321
# min      21.600000      12.800000     0.000000     0.000000     0.000000
# 25%      35.900000      35.833333    36.300000    35.500000    35.800000
# 50%      48.100000      48.133333    48.700000    47.500000    48.100000
# 75%      65.050000      65.166667    65.800000    64.500000    65.000000
# max     112.200000     112.033333   114.400000   109.500000   112.400000
#
#             EMA_10       SMA_10       EMA_20       SMA_20    BB_middle  \
# count  2863.000000  2863.000000  2863.000000  2863.000000  2863.000000
# mean     51.804630    51.807153    51.742518    51.744521    51.744521
# std      19.281964    19.318471    19.149276    19.212217    19.212217
# min      22.880572    22.920000    23.415183    23.415000    23.415000
# 25%      35.965569    35.845000    35.805320    35.892500    35.892500
# 50%      48.268870    48.190000    47.912310    48.175000    48.175000
# 75%      65.177406    65.135000    65.013644    65.125000    65.125000
# max     107.843891   108.360000   106.812710   107.605000   107.605000
#
#           BB_upper     BB_lower  Target_Close
# count  2863.000000  2863.000000   2863.000000
# mean     55.451296    48.037747     51.863535
# std      20.787697    18.089596     19.419157
# min      24.944052    20.053969     21.600000
# 25%      38.053193    33.178298     35.900000
# 50%      50.803798    45.127833     48.100000
# 75%      67.787210    61.510911     65.100000
# max     113.259179   104.944162    112.200000

# %% [markdown]
# Split the dataset(time based split):
#
#
# *   ✔ Train → past (0-80)
# *   ✔ Validation → future (but not latest) (80-90)
# *   ✔ Test → latest unseen data (90-100)
#
# using **standardscaler** this is best for timeseries datatype. also center of the data is 0 that's why i choose this.

# %%
from sklearn.preprocessing import StandardScaler

# -----------------------------
# Separate features and target
# -----------------------------
X = df_selected.drop(columns=['Target_Close'])
y = df_selected['Target_Close']

n = len(df_selected)

# -----------------------------
# Index boundaries
# -----------------------------
train_end = int(n * 0.80)
val_end   = int(n * 0.90)

# -----------------------------
# Chronological split
# -----------------------------
X_train = X.iloc[:train_end]
X_val   = X.iloc[train_end:val_end]
X_test  = X.iloc[val_end:]

y_train = y.iloc[:train_end]
y_val   = y.iloc[train_end:val_end]
y_test  = y.iloc[val_end:]

# -----------------------------
# Scaling (FIT ON TRAIN ONLY)
# -----------------------------
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled   = scaler.transform(X_val)
X_test_scaled  = scaler.transform(X_test)

# -----------------------------
# Sanity check
# -----------------------------
print(f"Train: {len(X_train_scaled)} ({len(X_train_scaled)/n*100:.1f}%)")
print(f"Val  : {len(X_val_scaled)} ({len(X_val_scaled)/n*100:.1f}%)")
print(f"Test : {len(X_test_scaled)} ({len(X_test_scaled)/n*100:.1f}%)")
# Out:
# Train: 2290 (80.0%)
# Val  : 286 (10.0%)
# Test : 287 (10.0%)

# %% [markdown]
# **Check scaling **

# %%
# ============================================
# 5. SCALING VERIFICATION
# ============================================
print("\n--- Scaling Check ---")

print("Train mean (first 5):", np.mean(X_train_scaled, axis=0)[:5])
print("Train std  (first 5):", np.std(X_train_scaled, axis=0)[:5])

print("\nVal mean (first 5):", np.mean(X_val_scaled, axis=0)[:5])
print("Val std  (first 5):", np.std(X_val_scaled, axis=0)[:5])

print("\nTest mean (first 5):", np.mean(X_test_scaled, axis=0)[:5])
print("Test std  (first 5):", np.std(X_test_scaled, axis=0)[:5])

# ============================================
# 6. NaN / INF CHECK
# ============================================
print("\nNaN check (train):", np.isnan(X_train_scaled).sum())
print("Inf check (train):", np.isinf(X_train_scaled).sum())

# ============================================
# 7. VISUAL CHECK
# ============================================
plt.figure()
plt.hist(X_train_scaled[:, 0], bins=50)
plt.title("Distribution of First Scaled Feature (Train Set)")
plt.xlabel("Scaled Value")
plt.ylabel("Frequency")
plt.show()

print("\n Scaling verified successfully. Pipeline is correct.")
# Out:
# --- Scaling Check ---
# Train mean (first 5): [ 1.48934722e-16 -4.96449073e-17 -9.92898146e-17  4.96449073e-17
#  -1.98579629e-16]
# Train std  (first 5): [1. 1. 1. 1. 1.]
#
# Val mean (first 5): [-0.43095504 -0.440599   -0.44647096 -0.44404407 -0.44086654]
# Val std  (first 5): [0.32814853 0.35025375 0.37502808 0.36977492 0.3725131 ]
#
# Test mean (first 5): [0.50805418 0.50152025 0.49768382 0.49851574 0.50164505]
# Test std  (first 5): [0.50647278 0.52253866 0.54784743 0.52797317 0.54194706]
#
# NaN check (train): 0
# Inf check (train): 0
#  Scaling verified successfully. Pipeline is correct.

# %% [markdown]
# # **Base line machine learning model like Regression, KNN and SVM**

# %% [markdown]
# Common Setup (Metrics & Imports)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
def evaluate_model(y_true, y_pred, model_name):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)

    print(f"{model_name} Results:")
    print(f"MAE  : {mae:.4f}")
    print(f"RMSE : {rmse:.4f}")
    print(f"R²   : {r2:.4f}")
    print("-" * 30)

    return mae, rmse, r2

# %% [markdown]
# **Linear Regression (Baseline)**

# %%
from sklearn.linear_model import LinearRegression

# Model
lr_model = LinearRegression()

# Train
lr_model.fit(X_train_scaled, y_train)

# Predict
y_pred_lr = lr_model.predict(X_test_scaled)

# Evaluate
evaluate_model(y_test, y_pred_lr, "Linear Regression")
# Out:
# Linear Regression Results:
# MAE  : 0.8698
# RMSE : 1.7316
# R²   : 0.9726
# ------------------------------
# (0.8698444880493894, np.float64(1.7316095097241933), 0.9726249167880019)

# %% [markdown]
# **Support Vector Regression (SVR)**
#
#
# *   **SVR Perform well amoung those base line models**

# %%
from sklearn.svm import SVR

# Model (RBF kernel is standard for finance)
svr_model = SVR(
    kernel='rbf',
    C=100,
    epsilon=0.1,
    gamma='scale'
)

# Train
svr_model.fit(X_train_scaled, y_train)

# Predict
y_pred_svr = svr_model.predict(X_test_scaled)

# Evaluate
evaluate_model(y_test, y_pred_svr, "Support Vector Regression (SVR)")
# Out:
# Support Vector Regression (SVR) Results:
# MAE  : 0.8381
# RMSE : 1.2822
# R²   : 0.9850
# ------------------------------
# (0.8380829300486866, np.float64(1.2821559078257814), 0.9849915031243515)

# %% [markdown]
# **K-Nearest Neighbors (KNN)**

# %%
from sklearn.neighbors import KNeighborsRegressor

# Model
knn_model = KNeighborsRegressor(
    n_neighbors=5,
    weights='distance',
    metric='minkowski'
)

# Train
knn_model.fit(X_train_scaled, y_train)

# Predict
y_pred_knn = knn_model.predict(X_test_scaled)

# Evaluate
evaluate_model(y_test, y_pred_knn, "KNN Regression")
# Out:
# KNN Regression Results:
# MAE  : 1.4478
# RMSE : 2.0700
# R²   : 0.9609
# ------------------------------
# (1.4477936872234831, np.float64(2.0700154011073564), 0.9608796549371679)

# %% [markdown]
# **Ridge Regression (Tuning)**

# %%
alphas = [0.001, 0.01, 0.1, 1, 10, 100]
import numpy as np
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

best_alpha = None
best_rmse = float('inf')

for alpha in alphas:
    ridge = Ridge(alpha=alpha)
    ridge.fit(X_train_scaled, y_train)

    y_val_pred = ridge.predict(X_val_scaled)
    rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))

    print(f"Alpha={alpha:<6} | Validation RMSE={rmse:.4f}")

    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha

print("\n Best alpha selected:", best_alpha)
# Out:
# Alpha=0.001  | Validation RMSE=1.4357
# Alpha=0.01   | Validation RMSE=1.3945
# Alpha=0.1    | Validation RMSE=1.1022
# Alpha=1      | Validation RMSE=1.0788
# Alpha=10     | Validation RMSE=1.8975
# Alpha=100    | Validation RMSE=1.9129
#
#  Best alpha selected: 1

# %%
ridge_final = Ridge(alpha=best_alpha)
ridge_final.fit(X_train_scaled, y_train)

y_test_pred = ridge_final.predict(X_test_scaled)

evaluate_model(y_test, y_test_pred, "Tuned Ridge Regression")
# Out:
# Tuned Ridge Regression Results:
# MAE  : 0.8478
# RMSE : 1.3202
# R²   : 0.9841
# ------------------------------
# (0.8478412830203481, np.float64(1.3201541767770846), 0.9840887305009702)

# %% [markdown]
# # Hyperparameters for deep learning models

# %%
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import (
    Input, Dense, LSTM, GRU, Dropout,
    LayerNormalization, MultiHeadAttention,
    GlobalAveragePooling1D
)
from tensorflow.keras.optimizers import Adam

# %%
# ================================
# GLOBAL HYPERPARAMETERS
# ================================

WINDOW_SIZE = 30          # sequence window length
BATCH_SIZE = 32
EPOCHS = 50
LEARNING_RATE = 0.001

# LSTM / GRU
RNN_UNITS = 64
RNN_DROPOUT = 0.2

# Transformer
NUM_HEADS = 4
TRANSFORMER_DIM = 64
FF_DIM = 128
TRANSFORMER_DROPOUT = 0.1

# Time2Vec
TIME2VEC_DIM = 8

# %% [markdown]
# **Sequence Windows**

# %%
import numpy as np

def create_sequences(X, y, window):
    X_seq, y_seq = [], []
    for i in range(len(X) - window):
        X_seq.append(X[i:i+window])
        y_seq.append(y[i+window])
    return np.array(X_seq), np.array(y_seq)

X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train.values, WINDOW_SIZE)
X_val_seq, y_val_seq = create_sequences(X_val_scaled, y_val.values, WINDOW_SIZE)
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test.values, WINDOW_SIZE)

# %% [markdown]
# **LSTM Model**

# %%
def build_lstm(input_shape):
    model = Sequential([
        LSTM(RNN_UNITS, return_sequences=False, input_shape=input_shape),
        Dropout(RNN_DROPOUT),
        Dense(1)
    ])

    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss='mse'
    )
    return model

lstm_model = build_lstm((WINDOW_SIZE, X_train_seq.shape[2]))
lstm_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 64)             │        19,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,777 (77.25 KB)
#  Trainable params: 19,777 (77.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **GRU Model**

# %%
def build_gru(input_shape):
    model = Sequential([
        GRU(RNN_UNITS, return_sequences=False, input_shape=input_shape),
        Dropout(RNN_DROPOUT),
        Dense(1)
    ])

    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss='mse'
    )
    return model

gru_model = build_gru((WINDOW_SIZE, X_train_seq.shape[2]))
gru_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_1 (GRU)                     │ (None, 64)             │        14,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,041 (58.75 KB)
#  Trainable params: 15,041 (58.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Transformer Model**

# %% [markdown]
# **Time2Vec Layer (Custom)**

# %%
class Time2Vec(tf.keras.layers.Layer):
    def __init__(self, kernel_size):
        super().__init__()
        self.kernel_size = kernel_size

    def build(self, input_shape):
        self.w = self.add_weight(
            name='weight',
            shape=(input_shape[-1], self.kernel_size),
            initializer='uniform',
            trainable=True
        )
        self.b = self.add_weight(
            name='bias',
            shape=(self.kernel_size,),
            initializer='uniform',
            trainable=True
        )

    def call(self, inputs):
        v = tf.linalg.matmul(inputs, self.w) + self.b
        return tf.concat([inputs, tf.math.sin(v)], axis=-1)

# %% [markdown]
# **Transformer Encoder only + Time2Vec Model**

# %%
def build_transformer(input_shape):
    inputs = Input(shape=input_shape)

    # Time2Vec Encoding
    t2v = Time2Vec(TIME2VEC_DIM)(inputs)

    # Self-Attention
    attn_output = MultiHeadAttention(
        num_heads=NUM_HEADS,
        key_dim=TRANSFORMER_DIM
    )(t2v, t2v)

    attn_output = Dropout(TRANSFORMER_DROPOUT)(attn_output)
    out1 = LayerNormalization()(t2v + attn_output)

    # Feed Forward Network
    ffn = Dense(FF_DIM, activation='relu')(out1)
    ffn = Dense(out1.shape[-1])(ffn)

    out2 = LayerNormalization()(out1 + ffn)

    # KERAS-SAFE pooling (FIX)
    x = GlobalAveragePooling1D()(out2)

    outputs = Dense(1)(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss='mse'
    )

    return model
transformer_model = build_transformer(
    (WINDOW_SIZE, X_train_seq.shape[2])
)

transformer_model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 30, 12)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time2_vec_1         │ (None, 30, 20)    │        104 │ input_layer_5[0]… │
# │ (Time2Vec)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 30, 20)    │     21,268 │ time2_vec_1[0][0… │
# │ (MultiHeadAttentio… │                   │            │ time2_vec_1[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 30, 20)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 30, 20)    │          0 │ time2_vec_1[0][0… │
# │                     │                   │            │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 20)    │         40 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 30, 128)   │      2,688 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 30, 20)    │      2,580 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 30, 20)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 20)    │         40 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 20)        │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1)         │         21 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,741 (104.46 KB)
#  Trainable params: 26,741 (104.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Train Any Model (Reusable)

# %%
def train_model(model, name):
    print(f"\nTraining {name}...")
    history = model.fit(
        X_train_seq, y_train_seq,
        validation_data=(X_val_seq, y_val_seq),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        verbose=1
    )
    return history

# %% [markdown]
# Train Models

# %%
train_model(lstm_model, "LSTM")
train_model(gru_model, "GRU")
train_model(transformer_model, "Transformer + Time2Vec")
# Out:
# Training LSTM...
# Epoch 1/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2591.1360 - val_loss: 967.3218
# Epoch 2/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1702.4102 - val_loss: 630.9729
# Epoch 3/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1354.7024 - val_loss: 427.4018
# Epoch 4/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1108.4697 - val_loss: 285.7599
# Epoch 5/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 923.9979 - val_loss: 187.3715
# Epoch 6/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 786.7557 - val_loss: 121.9655
# Epoch 7/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 682.8720 - val_loss: 81.2627
# Epoch 8/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 603.5610 - val_loss: 59.3249
# Epoch 9/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 548.1678 - val_loss: 49.0576
# Epoch 10/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 502.3549 - val_loss: 46.9769
# Epoch 11/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 475.9962 - val_loss: 46.1409
# Epoch 12/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 433.2487 - val_loss: 21.4888
# Epoch 13/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 347.1008 - val_loss: 9.9296
# Epoch 14/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 295.5396 - val_loss: 7.4307
# Epoch 15/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 257.5078 - val_loss: 5.9446
# Epoch 16/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 224.8238 - val_loss: 5.8013
# Epoch 17/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 197.5426 - val_loss: 5.3901
# Epoch 18/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 180.0242 - val_loss: 5.0060
# Epoch 19/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 160.2664 - val_loss: 5.3877
# Epoch 20/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 142.7262 - val_loss: 5.4136
# Epoch 21/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 127.7460 - val_loss: 4.3231
# Epoch 22/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 113.9748 - val_loss: 4.4983
# Epoch 23/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 106.6500 - val_loss: 4.5077
# Epoch 24/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 95.4776 - val_loss: 4.2676
# Epoch 25/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 87.0134 - val_loss: 3.8866
# Epoch 26/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 84.2744 - val_loss: 3.9001
# Epoch 27/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 77.3461 - val_loss: 3.7151
# Epoch 28/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 69.7619 - val_loss: 4.1921
# Epoch 29/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 69.1806 - val_loss: 3.6914
# Epoch 30/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 60.2021 - val_loss: 4.5045
# Epoch 31/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 58.2258 - val_loss: 3.7556
# Epoch 32/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 53.8336 - val_loss: 3.6467
# Epoch 33/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 50.1229 - val_loss: 3.3403
# Epoch 34/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 47.4440 - val_loss: 3.3109
# Epoch 35/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 45.4835 - val_loss: 3.1758
# Epoch 36/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 43.8585 - val_loss: 3.5188
# Epoch 37/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 43.2860 - val_loss: 3.2456
# Epoch 38/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 39.3373 - val_loss: 4.0755
# Epoch 39/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 37.1880 - val_loss: 3.1442
# Epoch 40/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 36.8985 - val_loss: 3.3122
# Epoch 41/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 32.8857 - val_loss: 3.3995
# Epoch 42/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 34.4674 - val_loss: 3.7469
# Epoch 43/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 33.6660 - val_loss: 3.6862
# Epoch 44/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 30.4409 - val_loss: 3.2218
# Epoch 45/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 28.3834 - val_loss: 3.7937
# Epoch 46/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 28.9179 - val_loss: 3.4909
# Epoch 47/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.5358 - val_loss: 3.6008
# Epoch 48/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.5646 - val_loss: 4.6173
# Epoch 49/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 26.3240 - val_loss: 3.9122
# Epoch 50/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.6851 - val_loss: 4.1372
#
# Training GRU...
# Epoch 1/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2695.1687 - val_loss: 1035.6205
# Epoch 2/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1760.2909 - val_loss: 686.3104
# Epoch 3/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1367.6766 - val_loss: 434.8632
# Epoch 4/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1095.6714 - val_loss: 275.0294
# Epoch 5/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 894.2230 - val_loss: 167.9038
# Epoch 6/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 753.5442 - val_loss: 110.1859
# Epoch 7/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 642.3040 - val_loss: 69.8422
# Epoch 8/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 542.9850 - val_loss: 45.0790
# Epoch 9/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 470.3870 - val_loss: 29.1537
# Epoch 10/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 406.9322 - val_loss: 18.3064
# Epoch 11/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 353.6500 - val_loss: 11.9604
# Epoch 12/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 314.4598 - val_loss: 9.2544
# Epoch 13/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 275.1411 - val_loss: 7.9515
# Epoch 14/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 245.5614 - val_loss: 7.6749
# Epoch 15/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 215.2282 - val_loss: 6.6046
# Epoch 16/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 191.1020 - val_loss: 6.6661
# Epoch 17/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 173.8600 - val_loss: 5.9980
# Epoch 18/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 153.9437 - val_loss: 5.2721
# Epoch 19/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 142.1151 - val_loss: 5.1781
# Epoch 20/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 128.4370 - val_loss: 5.5475
# Epoch 21/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 119.3380 - val_loss: 4.6101
# Epoch 22/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 108.1734 - val_loss: 4.0037
# Epoch 23/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 96.6360 - val_loss: 3.7519
# Epoch 24/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 91.0686 - val_loss: 3.7076
# Epoch 25/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 81.7438 - val_loss: 3.5034
# Epoch 26/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 77.4145 - val_loss: 3.4640
# Epoch 27/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 70.9771 - val_loss: 3.3794
# Epoch 28/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 64.7875 - val_loss: 3.5273
# Epoch 29/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 61.8127 - val_loss: 3.5023
# Epoch 30/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 57.5244 - val_loss: 3.8476
# Epoch 31/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 55.0238 - val_loss: 3.5995
# Epoch 32/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.8468 - val_loss: 3.8944
# Epoch 33/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 47.4126 - val_loss: 4.1505
# Epoch 34/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 45.4784 - val_loss: 3.6922
# Epoch 35/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 43.0378 - val_loss: 4.0647
# Epoch 36/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.0717 - val_loss: 8.6762
# Epoch 37/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.6873 - val_loss: 4.0751
# Epoch 38/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.4618 - val_loss: 5.3013
# Epoch 39/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 36.2452 - val_loss: 4.6071
# Epoch 40/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 34.0960 - val_loss: 4.4335
# Epoch 41/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 32.8499 - val_loss: 4.5362
# Epoch 42/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 30.9149 - val_loss: 4.4792
# Epoch 43/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 30.2877 - val_loss: 4.4441
# Epoch 44/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.7495 - val_loss: 5.8550
# Epoch 45/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 30.5516 - val_loss: 4.2582
# Epoch 46/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.3669 - val_loss: 5.2779
# Epoch 47/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.6005 - val_loss: 4.4937
# Epoch 48/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.7126 - val_loss: 4.6005
# Epoch 49/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.9799 - val_loss: 4.8111
# Epoch 50/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.9975 - val_loss: 5.3084
#
# Training Transformer + Time2Vec...
# Epoch 1/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - loss: 2566.0754 - val_loss: 1292.0852
# Epoch 2/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2236.0894 - val_loss: 1089.7372
# Epoch 3/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1961.9852 - val_loss: 864.4976
# Epoch 4/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1664.2129 - val_loss: 636.7163
# Epoch 5/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1367.1667 - val_loss: 429.9163
# Epoch 6/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1094.7964 - val_loss: 263.9960
# Epoch 7/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 868.0428 - val_loss: 145.3236
# Epoch 8/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 693.8843 - val_loss: 81.6087
# Epoch 9/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 543.9639 - val_loss: 39.7415
# Epoch 10/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 422.3400 - val_loss: 23.4294
# Epoch 11/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 332.2086 - val_loss: 25.4880
# Epoch 12/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 264.4428 - val_loss: 15.3174
# Epoch 13/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 207.3040 - val_loss: 27.7822
# Epoch 14/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 162.9021 - val_loss: 66.3522
# Epoch 15/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 131.7444 - val_loss: 57.2656
# Epoch 16/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 106.6051 - val_loss: 55.5199
# Epoch 17/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 87.9669 - val_loss: 56.4962
# Epoch 18/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 74.2578 - val_loss: 50.6015
# Epoch 19/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 62.1228 - val_loss: 56.3569
# Epoch 20/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 53.7987 - val_loss: 58.7869
# Epoch 21/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46.1535 - val_loss: 35.8100
# Epoch 22/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.1532 - val_loss: 34.6233
# Epoch 23/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.9717 - val_loss: 27.4470
# Epoch 24/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.6002 - val_loss: 26.5283
# Epoch 25/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.5157 - val_loss: 33.8392
# Epoch 26/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.3835 - val_loss: 15.7545
# Epoch 27/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.5467 - val_loss: 24.6588
# Epoch 28/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.4703 - val_loss: 40.1958
# Epoch 29/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.9120 - val_loss: 45.7802
# Epoch 30/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.9046 - val_loss: 34.1452
# Epoch 31/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.0992 - val_loss: 51.8319
# Epoch 32/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.9916 - val_loss: 43.6317
# Epoch 33/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.7020 - val_loss: 40.9877
# Epoch 34/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.4644 - val_loss: 41.4027
# Epoch 35/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.8338 - val_loss: 46.1976
# Epoch 36/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.1801 - val_loss: 43.8170
# Epoch 37/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.5141 - val_loss: 37.4500
# Epoch 38/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.3036 - val_loss: 43.2253
# Epoch 39/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6661 - val_loss: 47.8420
# Epoch 40/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3152 - val_loss: 42.6909
# Epoch 41/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8252 - val_loss: 40.2817
# Epoch 42/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7481 - val_loss: 43.2790
# Epoch 43/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.7363 - val_loss: 41.5177
# Epoch 44/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7055 - val_loss: 43.2066
# Epoch 45/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1344 - val_loss: 40.4910
# Epoch 46/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8247 - val_loss: 44.7334
# Epoch 47/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5700 - val_loss: 44.6846
# Epoch 48/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5050 - val_loss: 40.4464
# Epoch 49/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8670 - val_loss: 38.9623
# Epoch 50/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0419 - val_loss: 45.4450

# %% [markdown]
# **Evaluate (MAE, RMSE, R²)**

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_dl(model, name):
    y_pred = model.predict(X_test_seq).flatten()

    mae = mean_absolute_error(y_test_seq, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    r2 = r2_score(y_test_seq, y_pred)

    print(f"\n{name} Results:")
    print(f"MAE  : {mae:.4f}")
    print(f"RMSE : {rmse:.4f}")
    print(f"R²   : {r2:.4f}")

evaluate_dl(lstm_model, "LSTM")
evaluate_dl(gru_model, "GRU")
evaluate_dl(transformer_model, "Transformer + Time2Vec")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# LSTM Results:
# MAE  : 1.7663
# RMSE : 2.4604
# R²   : 0.9420
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# GRU Results:
# MAE  : 1.6761
# RMSE : 2.7375
# R²   : 0.9282
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
#
# Transformer + Time2Vec Results:
# MAE  : 2.5510
# RMSE : 3.3023
# R²   : 0.8955

# %% [markdown]
# # Diagram for predicted and actual

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_actual_vs_predicted(
    y_true,
    y_pred,
    model_name,
    num_points=200
):
    """
    Plot Actual vs Predicted prices

    y_true     : actual prices
    y_pred     : predicted prices
    model_name : name of the model (string)
    num_points : number of last points to plot
    """

    plt.figure(figsize=(12, 4))

    plt.plot(
        y_true[-num_points:],
        label="Actual Price",
        linewidth=2
    )

    plt.plot(
        y_pred[-num_points:],
        label="Predicted Price",
        linestyle="--"
    )

    plt.title(f"{model_name} – Actual vs Predicted Closing Price")
    plt.xlabel("Time Index")
    plt.ylabel("Closing Price")
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# SVR

# %%
y_pred_svr = svr_model.predict(X_test_scaled)

plot_actual_vs_predicted(
    y_true=y_test.values,
    y_pred=y_pred_svr,
    model_name="SVR"
)

# %% [markdown]
# Linear Regression

# %%
y_pred_lr = lr_model.predict(X_test_scaled)

plot_actual_vs_predicted(
    y_true=y_test.values,
    y_pred=y_pred_lr,
    model_name="Linear Regression"
)

# %% [markdown]
# Ridge Regression

# %%
y_pred_ridge = ridge_final.predict(X_test_scaled)

plot_actual_vs_predicted(
    y_true=y_test.values,
    y_pred=y_pred_ridge,
    model_name="Ridge Regression"
)

# %% [markdown]
# LSTM

# %%
y_pred_lstm = lstm_model.predict(X_test_seq).flatten()

plot_actual_vs_predicted(
    y_true=y_test_seq,
    y_pred=y_pred_lstm,
    model_name="LSTM"
)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# GRU

# %%
y_pred_gru = gru_model.predict(X_test_seq).flatten()

plot_actual_vs_predicted(
    y_true=y_test_seq,
    y_pred=y_pred_gru,
    model_name="GRU"
)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# Transformer

# %%
y_pred_transformer = transformer_model.predict(X_test_seq).flatten()

plot_actual_vs_predicted(
    y_true=y_test_seq,
    y_pred=y_pred_transformer,
    model_name="Transformer + Time2Vec"
)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ALL together deep learning models

# %%
plt.figure(figsize=(12, 5))

plt.plot(y_test_seq[-200:], label="Actual", linewidth=2)
plt.plot(y_pred_lstm[-200:], "--", label="LSTM")
plt.plot(y_pred_gru[-200:], "--", label="GRU")
plt.plot(y_pred_transformer[-200:], "--", label="Transformer")

plt.title("Actual vs Predicted Closing Price (Deep Learning Models)")
plt.xlabel("Time Index")
plt.ylabel("Closing Price")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Model Comparison Bar chart **

# %%
# ================================
# MODEL COMPARISON (RMSE)
# ================================

models = ["Linear", "SVR", "KNN", "Ridge", "LSTM", "GRU", "Transformer"]

rmse_values = [
    np.sqrt(mean_squared_error(y_test, y_pred_lr)),
    np.sqrt(mean_squared_error(y_test, y_pred_svr)),
    np.sqrt(mean_squared_error(y_test, y_pred_knn)),
    np.sqrt(mean_squared_error(y_test, y_test_pred)),  # ridge
    np.sqrt(mean_squared_error(y_test_seq, lstm_model.predict(X_test_seq).flatten())),
    np.sqrt(mean_squared_error(y_test_seq, gru_model.predict(X_test_seq).flatten())),
    np.sqrt(mean_squared_error(y_test_seq, transformer_model.predict(X_test_seq).flatten()))
]

plt.figure(figsize=(10, 5))
plt.bar(models, rmse_values)
plt.title("Model Comparison (RMSE)")
plt.ylabel("RMSE")
plt.xticks(rotation=45)
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# ================================
# MODEL COMPARISON (MAE)
# ================================

models = ["Linear", "SVR", "KNN", "Ridge", "LSTM", "GRU", "Transformer"]

rmse_values = [
    np.sqrt(mean_squared_error(y_test, y_pred_lr)),
    np.sqrt(mean_squared_error(y_test, y_pred_svr)),
    np.sqrt(mean_squared_error(y_test, y_pred_knn)),
    np.sqrt(mean_squared_error(y_test, y_test_pred)),  # ridge
    np.sqrt(mean_squared_error(y_test_seq, lstm_model.predict(X_test_seq).flatten())),
    np.sqrt(mean_squared_error(y_test_seq, gru_model.predict(X_test_seq).flatten())),
    np.sqrt(mean_squared_error(y_test_seq, transformer_model.predict(X_test_seq).flatten()))
]

plt.figure(figsize=(10, 5))
plt.bar(models, rmse_values)
plt.title("Model Comparison (MAE)")
plt.ylabel("MAE")
plt.xticks(rotation=45)
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# ================================
# MODEL COMPARISON (R²)
# ================================

models = ["Linear", "SVR", "KNN", "Ridge", "LSTM", "GRU", "Transformer"]

rmse_values = [
    np.sqrt(mean_squared_error(y_test, y_pred_lr)),
    np.sqrt(mean_squared_error(y_test, y_pred_svr)),
    np.sqrt(mean_squared_error(y_test, y_pred_knn)),
    np.sqrt(mean_squared_error(y_test, y_test_pred)),  # ridge
    np.sqrt(mean_squared_error(y_test_seq, lstm_model.predict(X_test_seq).flatten())),
    np.sqrt(mean_squared_error(y_test_seq, gru_model.predict(X_test_seq).flatten())),
    np.sqrt(mean_squared_error(y_test_seq, transformer_model.predict(X_test_seq).flatten()))
]

plt.figure(figsize=(10, 5))
plt.bar(models, rmse_values)
plt.title("Model Comparison (R²)")
plt.ylabel("R²")
plt.xticks(rotation=45)
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
